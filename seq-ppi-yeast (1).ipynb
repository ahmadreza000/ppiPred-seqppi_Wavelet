# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function


import sys
from embeddings.seq2tensor import s2t
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation, Dropout, Embedding, LSTM, Bidirectional, BatchNormalization, add
from tensorflow.keras.layers import Flatten, Reshape
from tensorflow.keras.layers import Concatenate, concatenate, subtract, multiply
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D, AveragePooling1D, GlobalAveragePooling1D
from tensorflow.keras.layers import GRU, Input

from tensorflow.keras.optimizers import Adam,  RMSprop

import os
import tensorflow as tf
import numpy as np
from tqdm import tqdm
import gc

#from tensorflow.compat.v1.keras.layers import Input, GRU
from numpy import linalg as LA
import scipy


#import keras.backend.tensorflow_backend as KTF
# """
# def get_session(gpu_fraction=0.25):
#     '''Assume that you have 6GB of GPU memory and want to allocate ~2GB'''

#     num_threads = os.environ.get('OMP_NUM_THREADS')
#     gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=gpu_fraction)

#     if num_threads:
#         return tf.Session(config=tf.ConfigProto(
#             gpu_options=gpu_options, intra_op_parallelism_threads=num_threads))
#     else:
#         return tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# KTF.set_session(get_session())
# """

# %%
# from tensorflow.keras.backend.tensorflow_backend import set_session
# fr0om keras.backend.tensorflow_backend import clear_session
# from keras.backend.tensorflow_backend import get_session
# import gc
# def reset_keras():
# #     sess = get_session()
# #     clear_session()
# #     sess.close()
# #     sess = get_session()
#     """
#     try:
#         del classifier # this is from global space - change this as you need
#     except:
#         pass
#     """
#     print(gc.collect()) # if it's done something you should see a number being outputted
#     # use the same config as you used to create the session
#     physical_devices = tf.config.experimental.list_physical_devices(device_type='GPU')
#     for device in physical_devices:
#         tf.config.experimental.set_memory_growth(device, True)
#     config = tf.compat.v1.ConfigProto()
#     config.gpu_options.per_process_gpu_memory_fraction = 0.9
#     config.gpu_options.allow_growth = True
# #     set_session(tf.compat.v1.Session(config=config))
# reset_keras()

# %%
# Note: if you use another PPI dataset, this needs to be changed to a corresponding dictionary file.
id2seq_file = './yeast/preprocessed/protein.dictionary.tsv'

id2index = {}
seqs = []
index = 0
for line in open(id2seq_file):
    line = line.strip().split('\t')
    id2index[line[0]] = index
    seqs.append(line[1])
    index += 1
seq_array = []
id2_aid = {}
sid = 0

# %%
seq_size = 2000
emb_files = ['./embeddings/physio.txt', './embeddings/string_vec5.txt', './embeddings/CTCoding_onehot.txt', './embeddings/vec7_CTC.txt']
use_emb = 3
hidden_dim = 25
n_epochs=50

# %%
# ds_file, label_index, rst_file, use_emb, hidden_dim
ds_file = './yeast/preprocessed/protein.actions.tsv'
label_index = 2
rst_file = 'results/15k_onehot_cnn.txt'
sid1_index = 0
sid2_index = 1
#if len(sys.argv) > 1:
#    ds_file, label_index, rst_file, use_emb, hidden_dim, n_epochs = sys.argv[1:]
#    label_index = int(label_index)
#    use_emb = int(use_emb)
#    hidden_dim = int(hidden_dim)
#    n_epochs = int(n_epochs)

# %%
seq2t = s2t(emb_files[use_emb])

# %%
max_data = -1
limit_data = max_data > 0
raw_data = []
skip_head = True
x = None
count = 0

# %%
for line in tqdm(open(ds_file)):
    if skip_head:
        skip_head = False
        continue
    line = line.rstrip('\n').rstrip('\r').split('\t')
    if id2index.get(line[sid1_index]) is None or id2index.get(line[sid2_index]) is None:
        continue
    if id2_aid.get(line[sid1_index]) is None:
        id2_aid[line[sid1_index]] = sid
        sid += 1
        seq_array.append(seqs[id2index[line[sid1_index]]])
    line[sid1_index] = id2_aid[line[sid1_index]]
    if id2_aid.get(line[sid2_index]) is None:
        id2_aid[line[sid2_index]] = sid
        sid += 1
        seq_array.append(seqs[id2index[line[sid2_index]]])
    line[sid2_index] = id2_aid[line[sid2_index]]
    raw_data.append(line)
    if limit_data:
        count += 1
        if count >= max_data:
            break
print (len(raw_data))
# Out:
# 11188it [00:00, 385713.24it/s]
# 11187

# %%
len_m_seq = np.array([len(line.split()) for line in seq_array])
avg_m_seq = int(np.average(len_m_seq)) + 1
max_m_seq = max(len_m_seq)
print (avg_m_seq, max_m_seq)
# Out:
# 2 1

# %%
dim = seq2t.dim
seq_tensor = np.array([seq2t.embed_normalized(line, seq_size) for line in tqdm(seq_array)])
seq_index1 = np.array([line[sid1_index] for line in tqdm(raw_data)])
seq_index2 = np.array([line[sid2_index] for line in tqdm(raw_data)])
print(seq_index1[:10])
print(dim)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 2497/2497 [00:00<00:00, 2862.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 11187/11187 [00:00<00:00, 3728085.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 11187/11187 [00:00<00:00, 3728381.31it/s]
# [ 0  2  4  6  8 10 10 13 15 17]
# 15

# %%
class_map = {'0':1,'1':0}
print(class_map)
class_labels = np.zeros((len(raw_data), 2))
for i in range(len(raw_data)):
    class_labels[i][class_map[raw_data[i][label_index]]] = 1.
# Out:
# {'0': 1, '1': 0}

# %%
#WAVELET CODE
#emb_files = ['/content/drive/MyDrive/Colab Notebooks/seq_ppi-master/embeddings/physio.txt', '/content/drive/MyDrive/Colab Notebooks/seq_ppi-master/embeddings/string_vec5.txt', '/content/drive/MyDrive/Colab Notebooks/seq_ppi-master/embeddings/CTCoding_onehot.txt', '/content/drive/MyDrive/Colab Notebooks/seq_ppi-master/embeddings/vec7_CTC.txt']
use_emb = 0
seq2t_W = s2t(emb_files[use_emb])

max_data = -1
limit_data = max_data > 0
raw_data = []
skip_head = True
x = None
count = 0

for line in tqdm(open(ds_file)):
    if skip_head:
        skip_head = False
        continue
    line = line.rstrip('\n').rstrip('\r').split('\t')
    if id2index.get(line[sid1_index]) is None or id2index.get(line[sid2_index]) is None:
        continue
    if id2_aid.get(line[sid1_index]) is None:
        id2_aid[line[sid1_index]] = sid
        sid += 1
        seq_array.append(seqs[id2index[line[sid1_index]]])
    line[sid1_index] = id2_aid[line[sid1_index]]
    if id2_aid.get(line[sid2_index]) is None:
        id2_aid[line[sid2_index]] = sid
        sid += 1
        seq_array.append(seqs[id2index[line[sid2_index]]])
    line[sid2_index] = id2_aid[line[sid2_index]]
    raw_data.append(line)
    if limit_data:
        count += 1
        if count >= max_data:
            break
print (len(raw_data))

len_m_seq = np.array([len(line.split()) for line in seq_array])
avg_m_seq = int(np.average(len_m_seq)) + 1
max_m_seq = max(len_m_seq)
print (avg_m_seq, max_m_seq)
# dim = seq2t_W.dim
seq_tensor_W = np.array([seq2t_W.embed_normalized(line, seq_size) for line in tqdm(seq_array)])
# Out:
# 11188it [00:00, 588737.02it/s]
# 11187
# 2 1
# 100%|████████████████████████████████████████████████████████████████████████████| 2497/2497 [00:00<00:00, 3267.59it/s]

# %%
#Wavelet feature generation
import pywt
import pywt.data
import scipy.special as special
from scipy.stats import entropy
from scipy.stats import linregress
from collections import Counter
from scipy.stats import kurtosis
from scipy.stats import moment
import pandas

# local variaable definition
# twoD_feature_of_Amino_acides_before_wavelet_transform = []  # Vectore for append all the wavelet produced matrixes
# coeffs = []

# counter = 0
# #T.W=[]

# T_W = np.zeros((seq_tensor_W.shape[0],35))

# #using different filterbanks name
# #for filter in ['db2','db3' ,'db4','db5','db6','db7','db8','db9','bior1.3','bior1.5','bior2.2','bior2.4','bior2.6','bior3.1','bior3.3','bior3.5','bior3.7','bior4.4','bior5.5','coif1','coif2','coif3','coif4','coif5','sym2','sym3','sym4','sym5','sym6','sym7','sym8']:
# print("Generating Features For ",'db2', " Filter bank started")

# %%
#wavelet first layer
#15 filters

coeffs = []

counter = -1

T_W = np.zeros((seq_tensor_W.shape[0],35,15))
for filter in ['db2','db3' ,'db4','db5','bior1.3','bior1.5','bior2.2','bior2.4','coif1','coif2','coif3','sym2','sym3','sym4','sym5']:
  print("Generating Features For ",filter, " Filter bank started")
  counter = counter + 1
  for i in range(seq_tensor_W.shape[0]):
            #if len(twoD_feature_of_Amino_acides_before_wavelet_transform) != 0:

                
                coeffs = pywt.dwt2(seq_tensor_W[i], filter)
                # LL, (LH, HL, HH),(LH1,HL1,HH1),(LH2, HL2, HH2),(LH3, HL3, HH3) = coeffs
                LL, (LH, HL, HH) = coeffs # separate the Approximate coefficient and detail coefficient to 4 signals

               #generating the criteria including max, min, median, average, Standard deviation,energy, entopy,
               #slope and SED error for details coeeficient towards approximate coefficient
               #overal energy and wavelength for overal signal and write in the file for each filter bank
                LLenergy = np.sqrt(np.sum(np.array(LL[-1]) ** 2)) / len(LL[-1])
                LHenergy = np.sqrt(np.sum(np.array(LH[-1]) ** 2)) / len(LH[-1])
                HLenergy = np.sqrt(np.sum(np.array(HL[-1]) ** 2)) / len(HL[-1])
                HHenergy = np.sqrt(np.sum(np.array(HH[-1]) ** 2)) / len(HH[-1])
                overalEnergy = np.sqrt(np.sum(np.array(coeffs[-1]) ** 2)) / len(coeffs[-1])
                LLwavelength = len(LL)

                LL = np.concatenate(LL)
                LH = np.concatenate(LH)
                HL = np.concatenate(HL)
                HH = np.concatenate(HH)

                LL1energy = np.sqrt(np.sum(np.array(LL[-1]) ** 2)) / len(LL)
                LH1energy = np.sqrt(np.sum(np.array(LH[-1]) ** 2)) / len(LH)
                HL1energy = np.sqrt(np.sum(np.array(HL[-1]) ** 2)) / len(HL)
                HH1energy = np.sqrt(np.sum(np.array(HH[-1]) ** 2)) / len(HH)

                LHslope, LHintercept, LHr_value, LHp_value, LHstd_err = linregress(LL, LH)
                HLslope, HLintercept, HLr_value, HLp_value, HLstd_err = linregress(LL, HL)
                HHslope, HHintercept, HHr_value, HHp_value, HHstd_err = linregress(LL, HH)

                maxLL = np.max(LL)
                minLL = np.min(LL)
                AvLL = np.average(LL)
                MedianLL = (minLL + maxLL) / 2

                pd_series = pandas.Series(LL)
                counts = pd_series.value_counts()
                LLentropy = entropy(counts)

                maxLH = np.max(LH)
                minLH = np.min(LH)
                AvLH = np.average(LH)
                MedianLH = (minLH + maxLH) / 2

                pd_series = pandas.Series(LH)
                counts = pd_series.value_counts()
                LHentropy = entropy(counts)

                maxHL = np.max(HL)
                minHL = np.min(HL)
                AvHL = np.average(HL)
                MedianHL = (minHL + maxHL) / 2

                pd_series = pandas.Series(HL)
                counts = pd_series.value_counts()
                HLentropy = entropy(counts)

                maxHH = np.max(HH)
                minHH = np.min(HH)
                AvHH = np.average(HH)
                MedianHH = (minHH + maxHH) / 2

                pd_series = pandas.Series(HH)
                counts = pd_series.value_counts()
                HHentropy = entropy(counts)

                # f3.write(str(maxLL) + '\t' + str(maxLH) + '\t' + str(maxHL) + '\t' + str(maxHH) + '\t' + str(
                #     minLL) + '\t' + str(minLH) + '\t' + str(minHL) + '\t' + str(minHH) + '\t' + str(
                #     AvLL) + '\t' + str(AvLH) + '\t' + str(AvHL) + '\t' + str(AvHH) + '\t' + str(
                #     MedianLL) + '\t' + str(
                #     MedianLH) + '\t' + str(MedianHL) + '\t' + str(MedianHH) + '\t' + str(
                #     np.std(LL)) + '\t' + str(
                #     np.std(LH)) + '\t' + str(np.std(HL)) + '\t' + str(np.std(HH)) + '\t' + str(
                #     LLentropy) + '\t' + str(LHentropy) + '\t' + str(HLentropy) + '\t' +
                #          str(HHentropy) + '\t' + str(LLenergy) + '\t' + str(LHenergy) + '\t' + str(
                #     HLenergy) + '\t' + str(HHenergy)

                #          + '\t' + str(LHslope) + '\t' + str(HLslope) + '\t' + str(HHslope) +
                #          '\t' + str(LHstd_err) + '\t' + str(HLstd_err) + '\t' + str(HHstd_err) + '\t' + str(
                #     LLwavelength) + '\t' + str(overalEnergy) + '\n')
                
                T_W[i,:,counter] = [maxLL,maxLH,maxHL,maxHH,minLL,minLH,minHL,minHH,AvLL,AvLH,AvHL,AvHH,MedianLL,MedianHL,MedianHH,np.std(LL),np.std(LH),np.std(HL),np.std(HH),LLentropy,LHentropy,HLentropy,HHentropy,LLenergy,LHenergy,HLenergy,HHenergy,LHslope,HLslope,HHslope,LHstd_err,HLstd_err,HHstd_err,LLwavelength,overalEnergy]


print("Feature Extraction Finished")
# Out:
# Generating Features For  db2  Filter bank started
# Generating Features For  db3  Filter bank started
# Generating Features For  db4  Filter bank started
# Generating Features For  db5  Filter bank started
# Generating Features For  bior1.3  Filter bank started
# Generating Features For  bior1.5  Filter bank started
# Generating Features For  bior2.2  Filter bank started
# Generating Features For  bior2.4  Filter bank started
# Generating Features For  coif1  Filter bank started
# Generating Features For  coif2  Filter bank started
# Generating Features For  coif3  Filter bank started
# Generating Features For  sym2  Filter bank started
# Generating Features For  sym3  Filter bank started
# Generating Features For  sym4  Filter bank started
# Generating Features For  sym5  Filter bank started
# Feature Extraction Finished

# %%
#wavelet last layer
#all filters

coeffs = []

counter = -1

T_W = np.zeros((seq_tensor_W.shape[0],35,31))
for filter in ['db2','db3' ,'db4','db5','db6','db7','db8','db9','bior1.3','bior1.5','bior2.2','bior2.4','bior2.6','bior3.1','bior3.3','bior3.5','bior3.7','bior4.4','bior5.5','coif1','coif2','coif3','coif4','coif5','sym2','sym3','sym4','sym5','sym6','sym7','sym8']:
  print("Generating Features For ",filter, " Filter bank started")
  counter = counter + 1
  for i in range(seq_tensor_W.shape[0]):
            #if len(twoD_feature_of_Amino_acides_before_wavelet_transform) != 0:

                
                coeffs = pywt.dwt2(seq_tensor_W[i], filter)
                # LL, (LH, HL, HH),(LH1,HL1,HH1),(LH2, HL2, HH2),(LH3, HL3, HH3) = coeffs
                LL, (LH, HL, HH) = coeffs # separate the Approximate coefficient and detail coefficient to 4 signals

               #generating the criteria including max, min, median, average, Standard deviation,energy, entopy,
               #slope and SED error for details coeeficient towards approximate coefficient
               #overal energy and wavelength for overal signal and write in the file for each filter bank
                LLenergy = np.sqrt(np.sum(np.array(LL[-1]) ** 2)) / len(LL[-1])
                LHenergy = np.sqrt(np.sum(np.array(LH[-1]) ** 2)) / len(LH[-1])
                HLenergy = np.sqrt(np.sum(np.array(HL[-1]) ** 2)) / len(HL[-1])
                HHenergy = np.sqrt(np.sum(np.array(HH[-1]) ** 2)) / len(HH[-1])
                overalEnergy = np.sqrt(np.sum(np.array(coeffs[-1]) ** 2)) / len(coeffs[-1])
                LLwavelength = len(LL)

                LL = np.concatenate(LL)
                LH = np.concatenate(LH)
                HL = np.concatenate(HL)
                HH = np.concatenate(HH)

                LL1energy = np.sqrt(np.sum(np.array(LL[-1]) ** 2)) / len(LL)
                LH1energy = np.sqrt(np.sum(np.array(LH[-1]) ** 2)) / len(LH)
                HL1energy = np.sqrt(np.sum(np.array(HL[-1]) ** 2)) / len(HL)
                HH1energy = np.sqrt(np.sum(np.array(HH[-1]) ** 2)) / len(HH)

                LHslope, LHintercept, LHr_value, LHp_value, LHstd_err = linregress(LL, LH)
                HLslope, HLintercept, HLr_value, HLp_value, HLstd_err = linregress(LL, HL)
                HHslope, HHintercept, HHr_value, HHp_value, HHstd_err = linregress(LL, HH)

                maxLL = np.max(LL)
                minLL = np.min(LL)
                AvLL = np.average(LL)
                MedianLL = (minLL + maxLL) / 2

                pd_series = pandas.Series(LL)
                counts = pd_series.value_counts()
                LLentropy = entropy(counts)

                maxLH = np.max(LH)
                minLH = np.min(LH)
                AvLH = np.average(LH)
                MedianLH = (minLH + maxLH) / 2

                pd_series = pandas.Series(LH)
                counts = pd_series.value_counts()
                LHentropy = entropy(counts)

                maxHL = np.max(HL)
                minHL = np.min(HL)
                AvHL = np.average(HL)
                MedianHL = (minHL + maxHL) / 2

                pd_series = pandas.Series(HL)
                counts = pd_series.value_counts()
                HLentropy = entropy(counts)

                maxHH = np.max(HH)
                minHH = np.min(HH)
                AvHH = np.average(HH)
                MedianHH = (minHH + maxHH) / 2

                pd_series = pandas.Series(HH)
                counts = pd_series.value_counts()
                HHentropy = entropy(counts)

                # f3.write(str(maxLL) + '\t' + str(maxLH) + '\t' + str(maxHL) + '\t' + str(maxHH) + '\t' + str(
                #     minLL) + '\t' + str(minLH) + '\t' + str(minHL) + '\t' + str(minHH) + '\t' + str(
                #     AvLL) + '\t' + str(AvLH) + '\t' + str(AvHL) + '\t' + str(AvHH) + '\t' + str(
                #     MedianLL) + '\t' + str(
                #     MedianLH) + '\t' + str(MedianHL) + '\t' + str(MedianHH) + '\t' + str(
                #     np.std(LL)) + '\t' + str(
                #     np.std(LH)) + '\t' + str(np.std(HL)) + '\t' + str(np.std(HH)) + '\t' + str(
                #     LLentropy) + '\t' + str(LHentropy) + '\t' + str(HLentropy) + '\t' +
                #          str(HHentropy) + '\t' + str(LLenergy) + '\t' + str(LHenergy) + '\t' + str(
                #     HLenergy) + '\t' + str(HHenergy)

                #          + '\t' + str(LHslope) + '\t' + str(HLslope) + '\t' + str(HHslope) +
                #          '\t' + str(LHstd_err) + '\t' + str(HLstd_err) + '\t' + str(HHstd_err) + '\t' + str(
                #     LLwavelength) + '\t' + str(overalEnergy) + '\n')
                
                T_W[i,:,counter] = [maxLL,maxLH,maxHL,maxHH,minLL,minLH,minHL,minHH,AvLL,AvLH,AvHL,AvHH,MedianLL,MedianHL,MedianHH,np.std(LL),np.std(LH),np.std(HL),np.std(HH),LLentropy,LHentropy,HLentropy,HHentropy,LLenergy,LHenergy,HLenergy,HHenergy,LHslope,HLslope,HHslope,LHstd_err,HLstd_err,HHstd_err,LLwavelength,overalEnergy]


print("Feature Extraction Finished")
# Out:
# Generating Features For  db2  Filter bank started
# Generating Features For  db3  Filter bank started
# Generating Features For  db4  Filter bank started
# Generating Features For  db5  Filter bank started
# Generating Features For  db6  Filter bank started
# Generating Features For  db7  Filter bank started
# Generating Features For  db8  Filter bank started
# Generating Features For  db9  Filter bank started
# Generating Features For  bior1.3  Filter bank started
# Generating Features For  bior1.5  Filter bank started
# Generating Features For  bior2.2  Filter bank started
# Generating Features For  bior2.4  Filter bank started
# Generating Features For  bior2.6  Filter bank started
# Generating Features For  bior3.1  Filter bank started
# Generating Features For  bior3.3  Filter bank started
# Generating Features For  bior3.5  Filter bank started
# Generating Features For  bior3.7  Filter bank started
# Generating Features For  bior4.4  Filter bank started
# Generating Features For  bior5.5  Filter bank started
# Generating Features For  coif1  Filter bank started
# Generating Features For  coif2  Filter bank started
# Generating Features For  coif3  Filter bank started
# Generating Features For  coif4  Filter bank started
# Generating Features For  coif5  Filter bank started
# Generating Features For  sym2  Filter bank started
# Generating Features For  sym3  Filter bank started
# Generating Features For  sym4  Filter bank started
# Generating Features For  sym5  Filter bank started
# Generating Features For  sym6  Filter bank started
# Generating Features For  sym7  Filter bank started
# Generating Features For  sym8  Filter bank started
# Feature Extraction Finished

# %%
#last layer
print(T_W.shape)
print(seq_tensor.shape)
waveletFeatureLastLayer = T_W.reshape(2497,35*31)
print(waveletFeatureLastLayer.shape)
waveletFeatureLastLayer=tf.keras.utils.normalize(waveletFeatureLastLayer, axis=0, order=1)
#dim=15
# Out:
# (2497, 35, 31)
# (2497, 2000, 15)
# (2497, 1085)

# %%
waveletFeatureLastLayer=np.zeros((2498,1085))

# %%
# save numpy array as csv file
from numpy import asarray
from numpy import savetxt
# save to csv file
savetxt('wldatanormal.csv', waveletFeatureLastLayer, delimiter=',')
savetxt('wldata.csv', T_W.reshape(2497,35*31), delimiter=',')

# %%
# load numpy array from csv file
from numpy import loadtxt
# load array
waveletFeatureLastLayer = loadtxt('wldatanormal.csv', delimiter=',')

# %%
print(sum(waveletFeatureLastLayer[:,1]))
print(waveletFeatureLastLayer[0])
# Out:
# 0.9999999999999964
# [0.00040737 0.00042487 0.00042293 ... 0.00043836 0.00043981 0.00043837]

# %%
#concate first layer
print(T_W.shape)
print(seq_tensor.shape)
new = np.concatenate((seq_tensor, T_W), axis=1)
print(new.shape)
#dim=15
# Out:
# (2497, 35, 31)
# (2497, 2000, 15)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 3>()
#       1 print(T_W.shape)
#       2 print(seq_tensor.shape)
# ----> 3 new = np.concatenate((seq_tensor, T_W), axis=1)
#       4 print(new.shape)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 2, the array at index 0 has size 15 and the array at index 1 has size 31

# %%
def build_model():
    seq_input1 = Input(shape=(2035, dim), name='seq1')
    seq_input2 = Input(shape=(2035, dim), name='seq2')
    l1=Conv1D(hidden_dim, 3)
    r1=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l2=Conv1D(hidden_dim, 3)
    r2=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l3=Conv1D(hidden_dim, 3)
    r3=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l4=Conv1D(hidden_dim, 3)
    r4=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l5=Conv1D(hidden_dim, 3)
    r5=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l6=Conv1D(hidden_dim, 3)
    s1=MaxPooling1D(3)(l1(seq_input1))
    s1=concatenate([r1(s1), s1])
    s1=MaxPooling1D(3)(l2(s1))
    s1=concatenate([r2(s1), s1])
    s1=MaxPooling1D(3)(l3(s1))
    s1=concatenate([r3(s1), s1])
    s1=MaxPooling1D(3)(l4(s1))
    s1=concatenate([r4(s1), s1])
    s1=MaxPooling1D(3)(l5(s1))
    s1=concatenate([r5(s1), s1])
    s1=l6(s1)
    s1=GlobalAveragePooling1D()(s1)
    s2=MaxPooling1D(3)(l1(seq_input2))
    s2=concatenate([r1(s2), s2])
    s2=MaxPooling1D(3)(l2(s2))
    s2=concatenate([r2(s2), s2])
    s2=MaxPooling1D(3)(l3(s2))
    s2=concatenate([r3(s2), s2])
    s2=MaxPooling1D(3)(l4(s2))
    s2=concatenate([r4(s2), s2])
    s2=MaxPooling1D(3)(l5(s2))
    s2=concatenate([r5(s2), s2])
    s2=l6(s2)
    s2=GlobalAveragePooling1D()(s2)
    merge_text = multiply([s1, s2])
    x = Dense(100, activation='linear')(merge_text)
    x = tf.keras.layers.LeakyReLU(alpha=0.3)(x)
    x = Dense(int((hidden_dim+7)/2), activation='linear')(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.3)(x)
    main_output = Dense(2, activation='softmax')(x)
    merge_model = Model(inputs=[seq_input1, seq_input2], outputs=[main_output])
    return merge_model

# %%
def build_model_lastLayer():
    seq_input1 = Input(shape=(2000, dim), name='seq1')
    seq_input2 = Input(shape=(2000, dim), name='seq2')
    wavelet_features_seq1 = Input(shape=(1085,), name='WaveletFeatureSeq1')
    wavelet_features_seq2 = Input(shape=(1085,), name='WaveletFeatureSeq2')
    l1=Conv1D(hidden_dim, 3)
    r1=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l2=Conv1D(hidden_dim, 3)
    r2=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l3=Conv1D(hidden_dim, 3)
    r3=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l4=Conv1D(hidden_dim, 3)
    r4=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l5=Conv1D(hidden_dim, 3)
    r5=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l6=Conv1D(hidden_dim, 3)
    s1=MaxPooling1D(3)(l1(seq_input1))
    s1=concatenate([r1(s1), s1])
    s1=MaxPooling1D(3)(l2(s1))
    s1=concatenate([r2(s1), s1])
    s1=MaxPooling1D(3)(l3(s1))
    s1=concatenate([r3(s1), s1])
    s1=MaxPooling1D(3)(l4(s1))
    s1=concatenate([r4(s1), s1])
    s1=MaxPooling1D(3)(l5(s1))
    s1=concatenate([r5(s1), s1])
    s1=l6(s1)
    s1=GlobalAveragePooling1D()(s1)
    s2=MaxPooling1D(3)(l1(seq_input2))
    s2=concatenate([r1(s2), s2])
    s2=MaxPooling1D(3)(l2(s2))
    s2=concatenate([r2(s2), s2])
    s2=MaxPooling1D(3)(l3(s2))
    s2=concatenate([r3(s2), s2])
    s2=MaxPooling1D(3)(l4(s2))
    s2=concatenate([r4(s2), s2])
    s2=MaxPooling1D(3)(l5(s2))
    s2=concatenate([r5(s2), s2])
    s2=l6(s2)
    s2=GlobalAveragePooling1D()(s2)
    merge_text = multiply([s1, s2])
    
    d1 = Dense(50, activation='relu')
    d2 = tf.keras.layers.LeakyReLU(alpha=0.3)
    d3 = Dense(10, activation='relu')
    d4 = tf.keras.layers.LeakyReLU(alpha=0.3)
    y=d4(d3(d2(d1(wavelet_features_seq1))))
    z=d4(d3(d2(d1(wavelet_features_seq2))))
    yz = concatenate([y,z])
    yz = Dense(1, activation='relu')(yz)
    yz = tf.keras.layers.LeakyReLU(alpha=0.3)(yz)
    con = concatenate([merge_text,yz])
    x = Dense(100, activation='relu')(con)
    x = tf.keras.layers.LeakyReLU(alpha=0.3)(x)
    x = Dense(int((hidden_dim+7)/2), activation='relu')(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.3)(x)
    main_output = Dense(2, activation='softmax')(x)
    merge_model = Model(inputs=[seq_input1, seq_input2,wavelet_features_seq1,wavelet_features_seq2], outputs=[main_output])
    return merge_model

# %%
def build_model_org():
    seq_input1 = Input(shape=(seq_size, dim), name='seq1')
    seq_input2 = Input(shape=(seq_size, dim), name='seq2')
    l1=Conv1D(hidden_dim, 3)
    r1=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l2=Conv1D(hidden_dim, 3)
    r2=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l3=Conv1D(hidden_dim, 3)
    r3=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l4=Conv1D(hidden_dim, 3)
    r4=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l5=Conv1D(hidden_dim, 3)
    r5=Bidirectional(GRU(hidden_dim, return_sequences=True))
    l6=Conv1D(hidden_dim, 3)
    s1=MaxPooling1D(3)(l1(seq_input1))
    s1=concatenate([r1(s1), s1])
    s1=MaxPooling1D(3)(l2(s1))
    s1=concatenate([r2(s1), s1])
    s1=MaxPooling1D(3)(l3(s1))
    s1=concatenate([r3(s1), s1])
    s1=MaxPooling1D(3)(l4(s1))
    s1=concatenate([r4(s1), s1])
    s1=MaxPooling1D(3)(l5(s1))
    s1=concatenate([r5(s1), s1])
    s1=l6(s1)
    s1=GlobalAveragePooling1D()(s1)
    s2=MaxPooling1D(3)(l1(seq_input2))
    s2=concatenate([r1(s2), s2])
    s2=MaxPooling1D(3)(l2(s2))
    s2=concatenate([r2(s2), s2])
    s2=MaxPooling1D(3)(l3(s2))
    s2=concatenate([r3(s2), s2])
    s2=MaxPooling1D(3)(l4(s2))
    s2=concatenate([r4(s2), s2])
    s2=MaxPooling1D(3)(l5(s2))
    s2=concatenate([r5(s2), s2])
    s2=l6(s2)
    s2=GlobalAveragePooling1D()(s2)
    merge_text = multiply([s1, s2])
    x = Dense(100, activation='linear')(merge_text)
    x = tf.keras.layers.LeakyReLU(alpha=0.3)(x)
    x = Dense(int((hidden_dim+7)/2), activation='linear')(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.3)(x)
    main_output = Dense(2, activation='softmax')(x)
    merge_model = Model(inputs=[seq_input1, seq_input2], outputs=[main_output])
    return merge_model

# %%
from tensorflow.keras.utils import plot_model
plot_model(build_model_lastLayer())

# %%
import graphviz
from keras.utils import plot_model
plot_model(build_model())

# %%
print(build_model_org().summary())
print(len(build_model_org().layers))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(build_model_org().summary())
#       2 print(len(build_model_org().layers))
#
# NameError: name 'build_model_org' is not defined

# %%
batch_size1 = 256
adam = Adam(learning_rate=0.001, amsgrad=True, epsilon=1e-6)
rms = RMSprop(learning_rate=0.001)

# %%
from sklearn.model_selection import KFold, ShuffleSplit
kf = KFold(n_splits=5, shuffle=True)
tries = 5
cur = 0
recalls = []
accuracy = []
total = []
total_truth = []
train_test = []
for train, test in kf.split(class_labels):
    if np.sum(class_labels[train], 0)[0] > 0.8 * len(train) or np.sum(class_labels[train], 0)[0] < 0.2 * len(train):
        continue
    train_test.append((train, test))
    cur += 1
    if cur >= tries:
        break

print (len(train_test))
# Out:
# 5

# %%
import datetime
tf.keras.backend.clear_session();
gc.collect()
# Out:
# 30

# %%
#copy below
####  new last layer
num_hit = 0.
num_total = 0.
num_pos = 0.
num_true_pos = 0.
num_false_pos = 0.
num_true_neg = 0.
num_false_neg = 0.
batch_size1 = 256
n_epochs=50
for train, test in train_test:
    tf.keras.backend.clear_session();
#     gc.collect()
#     gc.collect()
    merge_model = None
    merge_model = build_model_lastLayer()
    adam = Adam(learning_rate=0.001)
    callbacks=[]
    callbacks.append(tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor=0.1,patience=5,verbose=0,mode="auto",min_delta=0.0001,min_lr=0.00001))
    callbacks.append(tf.keras.callbacks.TensorBoard(log_dir=f'./logs/{str(datetime.datetime.now())[-5:]}', histogram_freq=0, write_graph=False))
    rms = RMSprop(learning_rate=0.001)
    merge_model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
    merge_model.fit([seq_tensor[seq_index1[train]], seq_tensor[seq_index2[train]], waveletFeatureLastLayer[seq_index1[train]], waveletFeatureLastLayer[seq_index2[train]]], class_labels[train], batch_size=batch_size1, epochs=n_epochs,callbacks=callbacks)
    #result1 = merge_model.evaluate([seq_tensor1[test], seq_tensor2[test]], class_labels[test])
    pred = merge_model.predict([seq_tensor[seq_index1[train]], seq_tensor[seq_index2[train]], waveletFeatureLastLayer[seq_index1[train]], waveletFeatureLastLayer[seq_index2[train]]])
    for i in range(len(class_labels[test])):
        num_total += 1
        if np.argmax(class_labels[test][i]) == np.argmax(pred[i]):
            num_hit += 1
        if class_labels[test][i][0] > 0.:
            num_pos += 1.
            if pred[i][0] > pred[i][1]:
                num_true_pos += 1
            else:
                num_false_neg += 1
        else:
            if pred[i][0] > pred[i][1]:
                num_false_pos += 1
            else:
                num_true_neg += 1
    
    print(num_hit,num_total,num_true_pos,num_false_pos,num_true_neg,num_false_neg)
    accuracy = num_hit / num_total
    prec = num_true_pos / (num_true_pos + num_false_pos)
    recall = num_true_pos / num_pos
    spec = num_true_neg / (num_true_neg + num_false_neg)
    f1 = 2. * prec * recall / (prec + recall)
    mcc = (num_true_pos * num_true_neg - num_false_pos * num_false_neg) / ((num_true_pos + num_true_neg) * (num_true_pos + num_false_neg) * (num_false_pos + num_true_neg) * (num_false_pos + num_false_neg)) ** 0.5
    print (accuracy, prec, recall, spec, f1, mcc)
#     reset_keras()
# Out:
# Epoch 1/50
# 35/35 [==============================] - 47s 596ms/step - loss: 0.6933 - accuracy: 0.4921
# Epoch 2/50
# 35/35 [==============================] - 6s 180ms/step - loss: 0.6931 - accuracy: 0.5055
# Epoch 3/50
# 35/35 [==============================] - 6s 180ms/step - loss: 0.6932 - accuracy: 0.5060
# Epoch 4/50
# 35/35 [==============================] - 6s 179ms/step - loss: 0.6933 - accuracy: 0.5026
# Epoch 5/50
# 35/35 [==============================] - 6s 180ms/step - loss: 0.6931 - accuracy: 0.5063
# Epoch 6/50
# 35/35 [==============================] - 6s 180ms/step - loss: 0.6932 - accuracy: 0.5020
# Epoch 7/50
# 35/35 [==============================] - 6s 180ms/step - loss: 0.6931 - accuracy: 0.5023
# Epoch 8/50
# 35/35 [==============================] - 6s 181ms/step - loss: 0.6930 - accuracy: 0.5110
# Epoch 9/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6929 - accuracy: 0.5196
# Epoch 10/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6928 - accuracy: 0.5183
# Epoch 11/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6927 - accuracy: 0.5236
# Epoch 12/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6925 - accuracy: 0.5236
# Epoch 13/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6927 - accuracy: 0.5231
# Epoch 14/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6924 - accuracy: 0.5220
# Epoch 15/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6923 - accuracy: 0.5264
# Epoch 16/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6923 - accuracy: 0.5236
# Epoch 17/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6920 - accuracy: 0.5265
# Epoch 18/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6919 - accuracy: 0.5267
# Epoch 19/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6920 - accuracy: 0.5265
# Epoch 20/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6918 - accuracy: 0.5268
# Epoch 21/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6918 - accuracy: 0.5250
# Epoch 22/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6920 - accuracy: 0.5249
# Epoch 23/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6912 - accuracy: 0.5290
# Epoch 24/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6916 - accuracy: 0.5298
# Epoch 25/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6912 - accuracy: 0.5264
# Epoch 26/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6908 - accuracy: 0.5355
# Epoch 27/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6894 - accuracy: 0.5421
# Epoch 28/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6833 - accuracy: 0.5633
# Epoch 29/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6798 - accuracy: 0.5624
# Epoch 30/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6747 - accuracy: 0.5718
# Epoch 31/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6733 - accuracy: 0.5722
# Epoch 32/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6693 - accuracy: 0.5781
# Epoch 33/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6700 - accuracy: 0.5807
# Epoch 34/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6675 - accuracy: 0.5802
# Epoch 35/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6668 - accuracy: 0.5825
# Epoch 36/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6644 - accuracy: 0.5822
# Epoch 37/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6651 - accuracy: 0.5888
# Epoch 38/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6623 - accuracy: 0.5888
# Epoch 39/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6621 - accuracy: 0.5878
# Epoch 40/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6597 - accuracy: 0.5940
# Epoch 41/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6589 - accuracy: 0.5899
# Epoch 42/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6580 - accuracy: 0.5916
# Epoch 43/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6563 - accuracy: 0.5976
# Epoch 44/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6550 - accuracy: 0.5977
# Epoch 45/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6532 - accuracy: 0.5979
# Epoch 46/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6519 - accuracy: 0.6042
# Epoch 47/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6513 - accuracy: 0.6034
# Epoch 48/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6516 - accuracy: 0.6077
# Epoch 49/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6484 - accuracy: 0.6076
# Epoch 50/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.6469 - accuracy: 0.6089
# 1102.0 2238.0 893.0 893.0 209.0 243.0
# 0.4924039320822163 0.5 0.7860915492957746 0.46238938053097345 0.6112251882272417 -0.024253278290432247
# Epoch 1/50
# 35/35 [==============================] - 46s 577ms/step - loss: 0.6932 - accuracy: 0.5183
# Epoch 2/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6928 - accuracy: 0.5213
# Epoch 3/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6926 - accuracy: 0.5187
# Epoch 4/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6920 - accuracy: 0.5320
# Epoch 5/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6914 - accuracy: 0.5327
# Epoch 6/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6899 - accuracy: 0.5354
# Epoch 7/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.6820 - accuracy: 0.5597
# Epoch 8/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6722 - accuracy: 0.5769
# Epoch 9/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6630 - accuracy: 0.5918
# Epoch 10/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6534 - accuracy: 0.6010
# Epoch 11/50
# 35/35 [==============================] - 6s 179ms/step - loss: 0.6480 - accuracy: 0.6090
# Epoch 12/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6313 - accuracy: 0.6337
# Epoch 13/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6199 - accuracy: 0.6441
# Epoch 14/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.6022 - accuracy: 0.6611
# Epoch 15/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.5565 - accuracy: 0.7135
# Epoch 16/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.5281 - accuracy: 0.7314
# Epoch 17/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.4617 - accuracy: 0.7831
# Epoch 18/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.3974 - accuracy: 0.8278
# Epoch 19/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.3292 - accuracy: 0.8611
# Epoch 20/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.2681 - accuracy: 0.8932
# Epoch 21/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.2300 - accuracy: 0.9102
# Epoch 22/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.1904 - accuracy: 0.9214
# Epoch 23/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.1502 - accuracy: 0.9352
# Epoch 24/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.1570 - accuracy: 0.9311
# Epoch 25/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.1256 - accuracy: 0.9456
# Epoch 26/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.1066 - accuracy: 0.9515
# Epoch 27/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.1131 - accuracy: 0.9493
# Epoch 28/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.1086 - accuracy: 0.9486
# Epoch 29/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0992 - accuracy: 0.9535
# Epoch 30/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0891 - accuracy: 0.9574
# Epoch 31/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0732 - accuracy: 0.9650
# Epoch 32/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0740 - accuracy: 0.9644
# Epoch 33/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0761 - accuracy: 0.9671
# Epoch 34/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0605 - accuracy: 0.9717
# Epoch 35/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0599 - accuracy: 0.9753
# Epoch 36/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0662 - accuracy: 0.9724
# Epoch 37/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0718 - accuracy: 0.9684
# Epoch 38/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0989 - accuracy: 0.9564
# Epoch 39/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0594 - accuracy: 0.9732
# Epoch 40/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0495 - accuracy: 0.9789
# Epoch 41/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0424 - accuracy: 0.9817
# Epoch 42/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0376 - accuracy: 0.9847
# Epoch 43/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0383 - accuracy: 0.9852
# Epoch 44/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0469 - accuracy: 0.9810
# Epoch 45/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0650 - accuracy: 0.9721
# Epoch 46/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0438 - accuracy: 0.9829
# Epoch 47/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0397 - accuracy: 0.9835
# Epoch 48/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0301 - accuracy: 0.9878
# Epoch 49/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0226 - accuracy: 0.9915
# Epoch 50/50
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0206 - accuracy: 0.9918
# 2229.0 4476.0 2007.0 2000.0 222.0 247.0
# 0.4979892761394102 0.5008734714250063 0.8904170363797693 0.47334754797441364 0.6411116435074269 -0.009672803632041966
# Epoch 1/50
# 35/35 [==============================] - 46s 579ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 2/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6932 - accuracy: 0.5034
# Epoch 3/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6932 - accuracy: 0.4989
# Epoch 4/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6932 - accuracy: 0.4989
# Epoch 5/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6932 - accuracy: 0.4873
# Epoch 6/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6934 - accuracy: 0.5003
# Epoch 7/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6930 - accuracy: 0.5011
# Epoch 8/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6930 - accuracy: 0.5011
# Epoch 9/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6928 - accuracy: 0.5011
# Epoch 10/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6928 - accuracy: 0.5045
# Epoch 11/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6926 - accuracy: 0.5144
# Epoch 12/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6924 - accuracy: 0.5209
# Epoch 13/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6923 - accuracy: 0.5265
# Epoch 14/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6922 - accuracy: 0.5257
# Epoch 15/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6921 - accuracy: 0.5332
# Epoch 16/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6919 - accuracy: 0.5314
# Epoch 17/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6918 - accuracy: 0.5323
# Epoch 18/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6917 - accuracy: 0.5363
# Epoch 19/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6915 - accuracy: 0.5392
# Epoch 20/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6910 - accuracy: 0.5415
# Epoch 21/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6911 - accuracy: 0.5318
# Epoch 22/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6899 - accuracy: 0.5419
# Epoch 23/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6896 - accuracy: 0.5410
# Epoch 24/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6869 - accuracy: 0.5517
# Epoch 25/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6883 - accuracy: 0.5523
# Epoch 26/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6832 - accuracy: 0.5627
# Epoch 27/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6812 - accuracy: 0.5694
# Epoch 28/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6801 - accuracy: 0.5666
# Epoch 29/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6761 - accuracy: 0.5774
# Epoch 30/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6744 - accuracy: 0.5780
# Epoch 31/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6714 - accuracy: 0.5856
# Epoch 32/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.6691 - accuracy: 0.5858
# Epoch 33/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6665 - accuracy: 0.5907
# Epoch 34/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6645 - accuracy: 0.5978
# Epoch 35/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6630 - accuracy: 0.6020
# Epoch 36/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.6604 - accuracy: 0.6076
# Epoch 37/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6550 - accuracy: 0.6166
# Epoch 38/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.6534 - accuracy: 0.6102
# Epoch 39/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6518 - accuracy: 0.6140
# Epoch 40/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6459 - accuracy: 0.6267
# Epoch 41/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6471 - accuracy: 0.6216
# Epoch 42/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6411 - accuracy: 0.6328
# Epoch 43/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6389 - accuracy: 0.6292
# Epoch 44/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6330 - accuracy: 0.6410
# Epoch 45/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6288 - accuracy: 0.6436
# Epoch 46/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6286 - accuracy: 0.6501
# Epoch 47/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6253 - accuracy: 0.6467
# Epoch 48/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6165 - accuracy: 0.6585
# Epoch 49/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6156 - accuracy: 0.6611
# Epoch 50/50
# 35/35 [==============================] - 6s 171ms/step - loss: 0.6167 - accuracy: 0.6581
# 3384.0 6713.0 2786.0 2753.0 598.0 576.0
# 0.504096529122598 0.5029788770536198 0.8286734086853064 0.5093696763202725 0.6259970789798899 0.007127831130734565
# Epoch 1/50
# 35/35 [==============================] - 47s 591ms/step - loss: 0.6933 - accuracy: 0.4962
# Epoch 2/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6932 - accuracy: 0.5011
# Epoch 3/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6931 - accuracy: 0.5012
# Epoch 4/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6930 - accuracy: 0.5022
# Epoch 5/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6932 - accuracy: 0.5038
# Epoch 6/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6930 - accuracy: 0.5056
# Epoch 7/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6933 - accuracy: 0.5036
# Epoch 8/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6932 - accuracy: 0.5032
# Epoch 9/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6933 - accuracy: 0.5063
# Epoch 10/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6932 - accuracy: 0.4980
# Epoch 11/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6932 - accuracy: 0.4979
# Epoch 12/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6931 - accuracy: 0.4998
# Epoch 13/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6931 - accuracy: 0.5098
# Epoch 14/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6930 - accuracy: 0.5226
# Epoch 15/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6930 - accuracy: 0.5153
# Epoch 16/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6930 - accuracy: 0.5155
# Epoch 17/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6930 - accuracy: 0.5164
# Epoch 18/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6930 - accuracy: 0.5162
# Epoch 19/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6930 - accuracy: 0.5154
# Epoch 20/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6930 - accuracy: 0.5171
# Epoch 21/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6929 - accuracy: 0.5185
# Epoch 22/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6929 - accuracy: 0.5162
# Epoch 23/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6929 - accuracy: 0.5164
# Epoch 24/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6929 - accuracy: 0.5172
# Epoch 25/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6929 - accuracy: 0.5158
# Epoch 26/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6929 - accuracy: 0.5182
# Epoch 27/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6928 - accuracy: 0.5166
# Epoch 28/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.6928 - accuracy: 0.5155
# Epoch 29/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6928 - accuracy: 0.5163
# Epoch 30/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6928 - accuracy: 0.5170
# Epoch 31/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6928 - accuracy: 0.5160
# Epoch 32/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6928 - accuracy: 0.5178
# Epoch 33/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6927 - accuracy: 0.5171
# Epoch 34/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6927 - accuracy: 0.5187
# Epoch 35/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6927 - accuracy: 0.5181
# Epoch 36/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.6927 - accuracy: 0.5165
# Epoch 37/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6926 - accuracy: 0.5182
# Epoch 38/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.6926 - accuracy: 0.5189
# Epoch 39/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6926 - accuracy: 0.5192
# Epoch 40/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6926 - accuracy: 0.5192
# Epoch 41/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.6926 - accuracy: 0.5192
# Epoch 42/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6926 - accuracy: 0.5194
# Epoch 43/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6926 - accuracy: 0.5207
# Epoch 44/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6925 - accuracy: 0.5190
# Epoch 45/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6925 - accuracy: 0.5211
# Epoch 46/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6925 - accuracy: 0.5208
# Epoch 47/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6925 - accuracy: 0.5215
# Epoch 48/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6925 - accuracy: 0.5213
# Epoch 49/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.6925 - accuracy: 0.5204
# Epoch 50/50
# 35/35 [==============================] - 6s 171ms/step - loss: 0.6925 - accuracy: 0.5230
# 4493.0 8950.0 3477.0 3472.0 1016.0 985.0
# 0.5020111731843575 0.5003597639948194 0.7792469744509188 0.5077461269365318 0.6094119709052669 0.005628457909089912
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[20], line 24
#      22 rms = RMSprop(learning_rate=0.001)
#      23 merge_model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
# ---> 24 merge_model.fit([seq_tensor[seq_index1[train]], seq_tensor[seq_index2[train]], waveletFeatureLastLayer[seq_index1[train]], waveletFeatureLastLayer[seq_index2[train]]], class_labels[train], batch_size=batch_size1, epochs=n_epochs,callbacks=callbacks)
#      25 #result1 = merge_model.evaluate([seq_tensor1[test], seq_tensor2[test]], class_labels[test])
#      26 pred = merge_model.predict([seq_tensor[seq_index1[train]], seq_tensor[seq_index2[train]], waveletFeatureLastLayer[seq_index1[train]], waveletFeatureLastLayer[seq_index2[train]]])
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1143, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1137   self._cluster_coordinator = cluster_coordinator.ClusterCoordinator(
#    1138       self.distribute_strategy)
#    1140 with self.distribute_strategy.scope(), \
#    1141      training_utils.RespectCompiledTrainableState(self):
#    1142   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1143   data_handler = data_adapter.get_data_handler(
#    1144       x=x,
#    1145       y=y,
#    1146       sample_weight=sample_weight,
#    1147       batch_size=batch_size,
#    1148       steps_per_epoch=steps_per_epoch,
#    1149       initial_epoch=initial_epoch,
#    1150       epochs=epochs,
#    1151       shuffle=shuffle,
#    1152       class_weight=class_weight,
#    1153       max_queue_size=max_queue_size,
#    1154       workers=workers,
#    1155       use_multiprocessing=use_multiprocessing,
#    1156       model=self,
#    1157       steps_per_execution=self._steps_per_execution)
#    1159   # Container that configures and calls `tf.keras.Callback`s.
#    1160   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1400, in get_data_handler(*args, **kwargs)
#    1398 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1399   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1400 return DataHandler(*args, **kwargs)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1155, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1152   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1154 adapter_cls = select_data_adapter(x, y)
# -> 1155 self._adapter = adapter_cls(
#    1156     x,
#    1157     y,
#    1158     batch_size=batch_size,
#    1159     steps=steps_per_epoch,
#    1160     epochs=epochs - initial_epoch,
#    1161     sample_weights=sample_weight,
#    1162     shuffle=shuffle,
#    1163     max_queue_size=max_queue_size,
#    1164     workers=workers,
#    1165     use_multiprocessing=use_multiprocessing,
#    1166     distribution_strategy=ds_context.get_strategy(),
#    1167     model=model)
#    1169 strategy = ds_context.get_strategy()
#    1171 self._current_step = 0
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:247, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     236 def __init__(self,
#     237              x,
#     238              y=None,
#    (...)
#     244              shuffle=False,
#     245              **kwargs):
#     246   super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 247   x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     248   sample_weight_modes = broadcast_sample_weight_modes(
#     249       sample_weights, sample_weight_modes)
#     251   # If sample_weights are not specified for an output use 1.0 as weights.
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1048, in _process_tensorlike(inputs)
#    1045     return _scipy_sparse_to_sparse_tensor(x)
#    1046   return x
# -> 1048 inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1049 return nest.list_to_tuple(inputs)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\util\nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\util\nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py:1043, in _process_tensorlike.<locals>._convert_numpy_and_scipy(x)
#    1041   if issubclass(x.dtype.type, np.floating):
#    1042     dtype = backend.floatx()
# -> 1043   return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1044 elif _is_scipy_sparse(x):
#    1045   return _scipy_sparse_to_sparse_tensor(x)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\util\dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\ops.py:1430, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1366 @tf_export("convert_to_tensor", v1=[])
#    1367 @dispatch.add_dispatch_support
#    1368 def convert_to_tensor_v2_with_dispatch(
#    1369     value, dtype=None, dtype_hint=None, name=None):
#    1370   """Converts the given `value` to a `Tensor`.
#    1371
#    1372   This function converts Python objects of various types to `Tensor`
#    (...)
#    1428     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1429   """
# -> 1430   return convert_to_tensor_v2(
#    1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\ops.py:1436, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1434 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1435   """Converts the given `value` to a `Tensor`."""
# -> 1436   return convert_to_tensor(
#    1437       value=value,
#    1438       dtype=dtype,
#    1439       name=name,
#    1440       preferred_dtype=dtype_hint,
#    1441       as_ref=False)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\profiler\trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\ops.py:1566, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1561       raise TypeError("convert_to_tensor did not convert to "
#    1562                       "the preferred dtype: %s vs %s " %
#    1563                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1565 if ret is None:
# -> 1566   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1568 if ret is NotImplemented:
#    1569   continue
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:52, in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py:271, in constant(value, dtype, shape, name)
#     174 @tf_export("constant", v1=[])
#     175 def constant(value, dtype=None, shape=None, name="Const"):
#     176   """Creates a constant tensor from a tensor-like object.
#     177
#     178   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py:283, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281     with trace.Trace("tf.constant"):
#     282       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     285 g = ops.get_default_graph()
#     286 tensor_value = attr_value_pb2.AttrValue()
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py:308, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# File ~\.conda\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\constant_op.py:106, in convert_to_eager_tensor(value, ctx, dtype)
#     104     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105 ctx.ensure_initialized()
# --> 106 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
# del build_model_lastLayer
# pred = merge_model.predict([seq_tensor[seq_index1[train]], seq_tensor[seq_index2[train]], waveletFeatureLastLayer[seq_index1[train]], waveletFeatureLastLayer[seq_index2[train]]])
from numba import cuda
cuda.select_device(0)
cuda.close()

# %%
num_hit = 0.
num_total = 0.
num_pos = 0.
num_true_pos = 0.
num_false_pos = 0.
num_true_neg = 0.
num_false_neg = 0.
for i in range(len(class_labels[test])):
        num_total += 1
        if np.argmax(class_labels[test][i]) == np.argmax(pred[i]):
            num_hit += 1
        if class_labels[test][i][0] > 0.:
            num_pos += 1.
            if pred[i][0] > pred[i][1]:
                num_true_pos += 1
            else:
                num_false_neg += 1
        else:
            if pred[i][0] > pred[i][1]:
                num_false_pos += 1
            else:
                num_true_neg += 1
print(num_hit,num_total,num_true_pos,num_false_pos,num_true_neg,num_false_neg)
from numba import cuda

def clear_gpu():
    device = cuda.get_current_device()
    device.reset()
# Out:
# 1144.0 2238.0 1141.0 1091.0 3.0 3.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 24
#      22                 num_true_neg += 1
#      23 print(num_hit,num_total,num_true_pos,num_false_pos,num_true_neg,num_false_neg)
# ---> 24 from numba import cuda
#      26 def clear_gpu():
#      27     device = cuda.get_current_device()
#
# ModuleNotFoundError: No module named 'numba'

# %%
print(num_hit,num_total,num_true_pos,num_false_pos,num_true_neg,num_false_neg)

merge_model.summary()
# Out:
# 1143.0 2238.0 1143.0 1095.0 0.0 0.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# seq1 (InputLayer)               [(None, 2000, 15)]   0
# __________________________________________________________________________________________________
# seq2 (InputLayer)               [(None, 2000, 15)]   0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1998, 50)     2300        seq1[0][0]
#                                                                  seq2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 666, 50)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 666, 50)      0           conv1d[1][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 666, 100)     30600       max_pooling1d[0][0]
#                                                                  max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 666, 150)     0           bidirectional[0][0]
#                                                                  max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 666, 150)     0           bidirectional[1][0]
#                                                                  max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 664, 50)      22550       concatenate[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 221, 50)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 221, 50)      0           conv1d_1[1][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 221, 100)     30600       max_pooling1d_1[0][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 221, 150)     0           bidirectional_1[0][0]
#                                                                  max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 221, 150)     0           bidirectional_1[1][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 219, 50)      22550       concatenate_1[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 73, 50)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 73, 50)       0           conv1d_2[1][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 73, 100)      30600       max_pooling1d_2[0][0]
#                                                                  max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 73, 150)      0           bidirectional_2[0][0]
#                                                                  max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 73, 150)      0           bidirectional_2[1][0]
#                                                                  max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 71, 50)       22550       concatenate_2[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 23, 50)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 23, 50)       0           conv1d_3[1][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 23, 100)      30600       max_pooling1d_3[0][0]
#                                                                  max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 23, 150)      0           bidirectional_3[0][0]
#                                                                  max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 23, 150)      0           bidirectional_3[1][0]
#                                                                  max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# WaveletFeatureSeq1 (InputLayer) [(None, 1085)]       0
# __________________________________________________________________________________________________
# WaveletFeatureSeq2 (InputLayer) [(None, 1085)]       0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 21, 50)       22550       concatenate_3[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 50)           54300       WaveletFeatureSeq1[0][0]
#                                                                  WaveletFeatureSeq2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 7, 50)        0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 7, 50)        0           conv1d_4[1][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 50)           0           dense[0][0]
#                                                                  dense[1][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 7, 100)       30600       max_pooling1d_4[0][0]
#                                                                  max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 20)           1020        leaky_re_lu[0][0]
#                                                                  leaky_re_lu[1][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 7, 150)       0           bidirectional_4[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 150)       0           bidirectional_4[1][0]
#                                                                  max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 20)           0           dense_1[0][0]
#                                                                  dense_1[1][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 5, 50)        22550       concatenate_4[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 40)           0           leaky_re_lu_1[0][0]
#                                                                  leaky_re_lu_1[1][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 50)           0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           conv1d_5[1][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           410         concatenate_10[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 50)           0           global_average_pooling1d[0][0]
#                                                                  global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 10)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 60)           0           multiply[0][0]
#                                                                  leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          6100        concatenate_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 100)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 28)           2828        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 28)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            58          leaky_re_lu_4[0][0]
# ==================================================================================================
# Total params: 332,766
# Trainable params: 332,766
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#copy below
####  new first layer
num_hit = 0.
num_total = 0.
num_pos = 0.
num_true_pos = 0.
num_false_pos = 0.
num_true_neg = 0.
num_false_neg = 0.

for train, test in train_test:
    merge_model = None
    merge_model = build_model()
    adam = Adam(learning_rate=0.001, amsgrad=True, epsilon=1e-6)
    rms = RMSprop(learning_rate=0.001)
    merge_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
    merge_model.fit([seq_tensor[new[train]], seq_tensor[new[train]]], class_labels[train], batch_size=batch_size1, epochs=n_epochs)
    #result1 = merge_model.evaluate([seq_tensor1[test], seq_tensor2[test]], class_labels[test])
    pred = merge_model.predict([seq_tensor[new[test]], seq_tensor[new[test]]])
    for i in range(len(class_labels[test])):
        num_total += 1
        if np.argmax(class_labels[test][i]) == np.argmax(pred[i]):
            num_hit += 1
        if class_labels[test][i][0] > 0.:
            num_pos += 1.
            if pred[i][0] > pred[i][1]:
                num_true_pos += 1
            else:
                num_false_neg += 1
        else:
            if pred[i][0] > pred[i][1]:
                num_false_pos += 1
            else:
                num_true_neg += 1
    accuracy = num_hit / num_total
    prec = num_true_pos / (num_true_pos + num_false_pos)
    recall = num_true_pos / num_pos
    spec = num_true_neg / (num_true_neg + num_false_neg)
    f1 = 2. * prec * recall / (prec + recall)
    mcc = (num_true_pos * num_true_neg - num_false_pos * num_false_neg) / ((num_true_pos + num_true_neg) * (num_true_pos + num_false_neg) * (num_false_pos + num_true_neg) * (num_false_pos + num_false_neg)) ** 0.5
    print (accuracy, prec, recall, spec, f1, mcc)

# %%
#copy below
# old
num_hit = 0.
num_total = 0.
num_pos = 0.
num_true_pos = 0.
num_false_pos = 0.
num_true_neg = 0.
num_false_neg = 0.

for train, test in train_test:
    #reset_keras()
    tf.keras.backend.clear_session();
    gc.collect()
    merge_model = None
    merge_model = build_model_org()
    adam = Adam(learning_rate=0.001, amsgrad=True, epsilon=1e-6)
    rms = RMSprop(learning_rate=0.001)
    merge_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
    merge_model.fit([seq_tensor[seq_index1[train]], seq_tensor[seq_index2[train]]], class_labels[train], batch_size=batch_size1, epochs=n_epochs)
    #result1 = merge_model.evaluate([seq_tensor1[test], seq_tensor2[test]], class_labels[test])
    pred = merge_model.predict([seq_tensor[seq_index1[test]], seq_tensor[seq_index2[test]]])
    for i in range(len(class_labels[test])):
        num_total += 1
        if np.argmax(class_labels[test][i]) == np.argmax(pred[i]):
            num_hit += 1
        if class_labels[test][i][0] > 0.:
            num_pos += 1.
            if pred[i][0] > pred[i][1]:
                num_true_pos += 1
            else:
                num_false_neg += 1
        else:
            if pred[i][0] > pred[i][1]:
                num_false_pos += 1
            else:
                num_true_neg += 1
    #del build_model_org
    
    accuracy = num_hit / num_total
    prec = num_true_pos / (num_true_pos + num_false_pos)
    recall = num_true_pos / num_pos
    spec = num_true_neg / (num_true_neg + num_false_neg)
    f1 = 2. * prec * recall / (prec + recall)
    mcc = (num_true_pos * num_true_neg - num_false_pos * num_false_neg) / ((num_true_pos + num_true_neg) * (num_true_pos + num_false_neg) * (num_false_pos + num_true_neg) * (num_false_pos + num_false_neg)) ** 0.5
    print (accuracy, prec, recall, spec, f1, mcc)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 44s 250ms/step - loss: 0.6934 - accuracy: 0.5014
# Epoch 2/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6939 - accuracy: 0.5101
# Epoch 3/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6939 - accuracy: 0.4979
# Epoch 4/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6930 - accuracy: 0.5024
# Epoch 5/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6932 - accuracy: 0.5008
# Epoch 6/50
# 35/35 [==============================] - 8s 231ms/step - loss: 0.6933 - accuracy: 0.4991
# Epoch 7/50
# 35/35 [==============================] - 8s 234ms/step - loss: 0.6929 - accuracy: 0.5151
# Epoch 8/50
# 35/35 [==============================] - 8s 238ms/step - loss: 0.6925 - accuracy: 0.5245
# Epoch 9/50
# 35/35 [==============================] - 8s 233ms/step - loss: 0.6939 - accuracy: 0.5061
# Epoch 10/50
# 35/35 [==============================] - 8s 233ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 11/50
# 35/35 [==============================] - 8s 230ms/step - loss: 0.6928 - accuracy: 0.5154
# Epoch 12/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6928 - accuracy: 0.5145
# Epoch 13/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6976 - accuracy: 0.5128
# Epoch 14/50
# 35/35 [==============================] - 8s 236ms/step - loss: 0.6935 - accuracy: 0.5025
# Epoch 15/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6940 - accuracy: 0.4879
# Epoch 16/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6925 - accuracy: 0.5138
# Epoch 17/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6938 - accuracy: 0.5041
# Epoch 18/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6930 - accuracy: 0.5092
# Epoch 19/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6923 - accuracy: 0.5167
# Epoch 20/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6926 - accuracy: 0.5141
# Epoch 21/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6926 - accuracy: 0.5166
# Epoch 22/50
# 35/35 [==============================] - 8s 223ms/step - loss: 0.6925 - accuracy: 0.5242
# Epoch 23/50
# 35/35 [==============================] - 8s 230ms/step - loss: 0.6918 - accuracy: 0.5255
# Epoch 24/50
# 35/35 [==============================] - 8s 231ms/step - loss: 0.6879 - accuracy: 0.5435
# Epoch 25/50
# 35/35 [==============================] - 8s 231ms/step - loss: 0.6929 - accuracy: 0.5115
# Epoch 26/50
# 35/35 [==============================] - 8s 231ms/step - loss: 0.6855 - accuracy: 0.5534
# Epoch 27/50
# 35/35 [==============================] - 8s 230ms/step - loss: 0.6840 - accuracy: 0.5519
# Epoch 28/50
# 35/35 [==============================] - 8s 231ms/step - loss: 0.6807 - accuracy: 0.5461
# Epoch 29/50
# 35/35 [==============================] - 8s 230ms/step - loss: 0.6917 - accuracy: 0.5236
# Epoch 30/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6728 - accuracy: 0.5782
# Epoch 31/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6806 - accuracy: 0.5452
# Epoch 32/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6904 - accuracy: 0.5348
# Epoch 33/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6646 - accuracy: 0.5869
# Epoch 34/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6574 - accuracy: 0.5933
# Epoch 35/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6329 - accuracy: 0.6232
# Epoch 36/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6091 - accuracy: 0.6467
# Epoch 37/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.5548 - accuracy: 0.7006
# Epoch 38/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.4739 - accuracy: 0.7728
# Epoch 39/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.3706 - accuracy: 0.8376
# Epoch 40/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.2445 - accuracy: 0.8946
# Epoch 41/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.1640 - accuracy: 0.9235
# Epoch 42/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.1304 - accuracy: 0.9392
# Epoch 43/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.1226 - accuracy: 0.9423
# Epoch 44/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.1054 - accuracy: 0.9515
# Epoch 45/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.0897 - accuracy: 0.9551
# Epoch 46/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.0754 - accuracy: 0.9635
# Epoch 47/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.0747 - accuracy: 0.9664
# Epoch 48/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.0630 - accuracy: 0.9717
# Epoch 49/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.0541 - accuracy: 0.9768
# Epoch 50/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.0565 - accuracy: 0.9763
# 0.9410187667560321 0.9423604757548033 0.9372156505914467 0.9397379912663756 0.9397810218978101 1.8713966972561527
# Epoch 1/50
# 35/35 [==============================] - 40s 237ms/step - loss: 0.6938 - accuracy: 0.5147
# Epoch 2/50
# 35/35 [==============================] - 8s 235ms/step - loss: 0.6929 - accuracy: 0.5084
# Epoch 3/50
# 35/35 [==============================] - 8s 233ms/step - loss: 0.6935 - accuracy: 0.5094
# Epoch 4/50
# 35/35 [==============================] - 8s 233ms/step - loss: 0.6935 - accuracy: 0.5065
# Epoch 5/50
# 35/35 [==============================] - 8s 234ms/step - loss: 0.6932 - accuracy: 0.5042
# Epoch 6/50
# 35/35 [==============================] - 8s 230ms/step - loss: 0.6928 - accuracy: 0.5125
# Epoch 7/50
# 35/35 [==============================] - 8s 223ms/step - loss: 0.6931 - accuracy: 0.5013
# Epoch 8/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6928 - accuracy: 0.5109
# Epoch 9/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6934 - accuracy: 0.5015
# Epoch 10/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6931 - accuracy: 0.4989
# Epoch 11/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6929 - accuracy: 0.5157
# Epoch 12/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6930 - accuracy: 0.5059
# Epoch 13/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6929 - accuracy: 0.5100
# Epoch 14/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6922 - accuracy: 0.5245
# Epoch 15/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6920 - accuracy: 0.5206
# Epoch 16/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6929 - accuracy: 0.5175
# Epoch 17/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6925 - accuracy: 0.5132
# Epoch 18/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6900 - accuracy: 0.5367
# Epoch 19/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6940 - accuracy: 0.5235
# Epoch 20/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6941 - accuracy: 0.5049
# Epoch 21/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6913 - accuracy: 0.5232
# Epoch 22/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6940 - accuracy: 0.5357
# Epoch 23/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6910 - accuracy: 0.5369
# Epoch 24/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6756 - accuracy: 0.5838
# Epoch 25/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6896 - accuracy: 0.5626
# Epoch 26/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6743 - accuracy: 0.5777
# Epoch 27/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6695 - accuracy: 0.6069
# Epoch 28/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6366 - accuracy: 0.6354
# Epoch 29/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.5487 - accuracy: 0.7221
# Epoch 30/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.4049 - accuracy: 0.8170
# Epoch 31/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.3079 - accuracy: 0.8659
# Epoch 32/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.1737 - accuracy: 0.9243
# Epoch 33/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.1437 - accuracy: 0.9337
# Epoch 34/50
# 35/35 [==============================] - 8s 232ms/step - loss: 0.1408 - accuracy: 0.9350
# Epoch 35/50
# 35/35 [==============================] - 8s 232ms/step - loss: 0.1248 - accuracy: 0.9395
# Epoch 36/50
# 35/35 [==============================] - 8s 233ms/step - loss: 0.1047 - accuracy: 0.9468
# Epoch 37/50
# 35/35 [==============================] - 8s 232ms/step - loss: 0.0918 - accuracy: 0.9543
# Epoch 38/50
# 35/35 [==============================] - 8s 233ms/step - loss: 0.1126 - accuracy: 0.9469
# Epoch 39/50
# 35/35 [==============================] - 8s 232ms/step - loss: 0.1059 - accuracy: 0.9489
# Epoch 40/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.0829 - accuracy: 0.9569
# Epoch 41/50
# 35/35 [==============================] - 8s 223ms/step - loss: 0.0836 - accuracy: 0.9564
# Epoch 42/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.0779 - accuracy: 0.9610
# Epoch 43/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.0888 - accuracy: 0.9550
# Epoch 44/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.0913 - accuracy: 0.9561
# Epoch 45/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.0818 - accuracy: 0.9617
# Epoch 46/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.0955 - accuracy: 0.9541
# Epoch 47/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.0799 - accuracy: 0.9610
# Epoch 48/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.0698 - accuracy: 0.9656
# Epoch 49/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.0679 - accuracy: 0.9670
# Epoch 50/50
# 35/35 [==============================] - 8s 222ms/step - loss: 0.0661 - accuracy: 0.9676
# 0.9454870420017873 0.9555966697502313 0.9331526648599819 0.9360414866032843 0.9442413162705667 1.9615746401886243
# Epoch 1/50
# 35/35 [==============================] - 39s 250ms/step - loss: 0.6947 - accuracy: 0.5098
# Epoch 2/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6933 - accuracy: 0.5133
# Epoch 3/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6933 - accuracy: 0.4977
# Epoch 4/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6934 - accuracy: 0.5030
# Epoch 5/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6930 - accuracy: 0.5161
# Epoch 6/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6932 - accuracy: 0.5037
# Epoch 7/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6935 - accuracy: 0.5095
# Epoch 8/50
# 35/35 [==============================] - 8s 232ms/step - loss: 0.6930 - accuracy: 0.5068
# Epoch 9/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6937 - accuracy: 0.5012
# Epoch 10/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6930 - accuracy: 0.5069
# Epoch 11/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6932 - accuracy: 0.5004
# Epoch 12/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6928 - accuracy: 0.5136
# Epoch 13/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6935 - accuracy: 0.5097
# Epoch 14/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 15/50
# 35/35 [==============================] - 8s 231ms/step - loss: 0.6931 - accuracy: 0.5095
# Epoch 16/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6931 - accuracy: 0.5151
# Epoch 17/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6932 - accuracy: 0.4943
# Epoch 18/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6935 - accuracy: 0.5076
# Epoch 19/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6930 - accuracy: 0.5108
# Epoch 20/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6927 - accuracy: 0.5164
# Epoch 21/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6937 - accuracy: 0.4935
# Epoch 22/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6934 - accuracy: 0.4951
# Epoch 23/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6931 - accuracy: 0.4992
# Epoch 24/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6928 - accuracy: 0.5097
# Epoch 25/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6931 - accuracy: 0.5022
# Epoch 26/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6925 - accuracy: 0.5132
# Epoch 27/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6924 - accuracy: 0.5267
# Epoch 28/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6935 - accuracy: 0.5118
# Epoch 29/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6929 - accuracy: 0.5144
# Epoch 30/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6925 - accuracy: 0.5164
# Epoch 31/50
# 35/35 [==============================] - 8s 222ms/step - loss: 0.6925 - accuracy: 0.5198
# Epoch 32/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6927 - accuracy: 0.5207
# Epoch 33/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6928 - accuracy: 0.5158
# Epoch 34/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6920 - accuracy: 0.5211
# Epoch 35/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6931 - accuracy: 0.5156
# Epoch 36/50
# 35/35 [==============================] - 8s 230ms/step - loss: 0.6916 - accuracy: 0.5264
# Epoch 37/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6918 - accuracy: 0.5266
# Epoch 38/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6916 - accuracy: 0.5251
# Epoch 39/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6897 - accuracy: 0.5409
# Epoch 40/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6934 - accuracy: 0.5106
# Epoch 41/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6924 - accuracy: 0.5192
# Epoch 42/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6859 - accuracy: 0.5399
# Epoch 43/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6867 - accuracy: 0.5277
# Epoch 44/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6892 - accuracy: 0.5456
# Epoch 45/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6786 - accuracy: 0.5779
# Epoch 46/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6794 - accuracy: 0.5458
# Epoch 47/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6958 - accuracy: 0.5142
# Epoch 48/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6894 - accuracy: 0.5336
# Epoch 49/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6538 - accuracy: 0.5981
# Epoch 50/50
# 35/35 [==============================] - 8s 220ms/step - loss: 0.6524 - accuracy: 0.5939
# 0.8356919410099807 0.8262001156737999 0.8505507591545103 0.8457757296466973 0.838198621094323 0.9058867891223668
# Epoch 1/50
# 35/35 [==============================] - 39s 228ms/step - loss: 0.6937 - accuracy: 0.4917
# Epoch 2/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6936 - accuracy: 0.5039
# Epoch 3/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6933 - accuracy: 0.5059
# Epoch 4/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6937 - accuracy: 0.5047
# Epoch 5/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6932 - accuracy: 0.5012
# Epoch 6/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6931 - accuracy: 0.5022
# Epoch 7/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6929 - accuracy: 0.5220
# Epoch 8/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 9/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6933 - accuracy: 0.4968
# Epoch 10/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6932 - accuracy: 0.4946
# Epoch 11/50
# 35/35 [==============================] - 8s 223ms/step - loss: 0.6932 - accuracy: 0.5025
# Epoch 12/50
# 35/35 [==============================] - 8s 221ms/step - loss: 0.6936 - accuracy: 0.5088
# Epoch 13/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6932 - accuracy: 0.4979
# Epoch 14/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6932 - accuracy: 0.5060
# Epoch 15/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6935 - accuracy: 0.5086
# Epoch 16/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6931 - accuracy: 0.5055
# Epoch 17/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6933 - accuracy: 0.4959
# Epoch 18/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6934 - accuracy: 0.4978
# Epoch 19/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6931 - accuracy: 0.5028
# Epoch 20/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6930 - accuracy: 0.5085
# Epoch 21/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6929 - accuracy: 0.5093
# Epoch 22/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6929 - accuracy: 0.5091
# Epoch 23/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6925 - accuracy: 0.5274
# Epoch 24/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6935 - accuracy: 0.5078
# Epoch 25/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6931 - accuracy: 0.5212
# Epoch 26/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6931 - accuracy: 0.5085
# Epoch 27/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6929 - accuracy: 0.5206
# Epoch 28/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6928 - accuracy: 0.5270
# Epoch 29/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6915 - accuracy: 0.5375
# Epoch 30/50
# 35/35 [==============================] - 8s 222ms/step - loss: 0.6897 - accuracy: 0.5466
# Epoch 31/50
# 35/35 [==============================] - 8s 223ms/step - loss: 0.6966 - accuracy: 0.5086
# Epoch 32/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6932 - accuracy: 0.5094
# Epoch 33/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6935 - accuracy: 0.5051
# Epoch 34/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6936 - accuracy: 0.5091
# Epoch 35/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6937 - accuracy: 0.4901
# Epoch 36/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 37/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6925 - accuracy: 0.5211
# Epoch 38/50
# 35/35 [==============================] - 8s 223ms/step - loss: 0.6924 - accuracy: 0.5226
# Epoch 39/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6928 - accuracy: 0.5135
# Epoch 40/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6895 - accuracy: 0.5371
# Epoch 41/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6954 - accuracy: 0.5122
# Epoch 42/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6873 - accuracy: 0.5475
# Epoch 43/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6869 - accuracy: 0.5369
# Epoch 44/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6777 - accuracy: 0.5701
# Epoch 45/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6618 - accuracy: 0.5952
# Epoch 46/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.6374 - accuracy: 0.6174
# Epoch 47/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.5633 - accuracy: 0.6984
# Epoch 48/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.4975 - accuracy: 0.7626
# Epoch 49/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.3389 - accuracy: 0.8526
# Epoch 50/50
# 35/35 [==============================] - 8s 220ms/step - loss: 0.1947 - accuracy: 0.9170
# 0.8549720670391061 0.8481236203090508 0.8629829290206649 0.8619909502262444 0.8554887552883546 1.0081769523064248
# Epoch 1/50
# 35/35 [==============================] - 38s 226ms/step - loss: 0.6936 - accuracy: 0.4975
# Epoch 2/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6938 - accuracy: 0.5120
# Epoch 3/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.6932 - accuracy: 0.5075
# Epoch 4/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 5/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6930 - accuracy: 0.5107
# Epoch 6/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6927 - accuracy: 0.5175
# Epoch 7/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6934 - accuracy: 0.5104
# Epoch 8/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6929 - accuracy: 0.5137
# Epoch 9/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6933 - accuracy: 0.5015
# Epoch 10/50
# 35/35 [==============================] - 8s 226ms/step - loss: 0.6932 - accuracy: 0.5050
# Epoch 11/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.6931 - accuracy: 0.5108
# Epoch 12/50
# 35/35 [==============================] - 8s 224ms/step - loss: 0.6930 - accuracy: 0.5123
# Epoch 13/50
# 35/35 [==============================] - 8s 223ms/step - loss: 0.6936 - accuracy: 0.5007
# Epoch 14/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6934 - accuracy: 0.5099
# Epoch 15/50
# 35/35 [==============================] - 8s 222ms/step - loss: 0.6932 - accuracy: 0.5105
# Epoch 16/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.6931 - accuracy: 0.5045
# Epoch 17/50
# 35/35 [==============================] - 8s 219ms/step - loss: 0.6924 - accuracy: 0.5182
# Epoch 18/50
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6922 - accuracy: 0.5210
# Epoch 19/50
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6933 - accuracy: 0.5029
# Epoch 20/50
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6927 - accuracy: 0.5079
# Epoch 21/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.6929 - accuracy: 0.5099
# Epoch 22/50
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6928 - accuracy: 0.5185
# Epoch 23/50
# 35/35 [==============================] - 8s 216ms/step - loss: 0.6925 - accuracy: 0.5193
# Epoch 24/50
# 35/35 [==============================] - 8s 219ms/step - loss: 0.6925 - accuracy: 0.5164
# Epoch 25/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.6920 - accuracy: 0.5242
# Epoch 26/50
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6939 - accuracy: 0.5055
# Epoch 27/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.6932 - accuracy: 0.5076
# Epoch 28/50
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6930 - accuracy: 0.5095
# Epoch 29/50
# 35/35 [==============================] - 8s 219ms/step - loss: 0.6923 - accuracy: 0.5221
# Epoch 30/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.6880 - accuracy: 0.5453
# Epoch 31/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.6829 - accuracy: 0.5558
# Epoch 32/50
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6712 - accuracy: 0.5788
# Epoch 33/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.6504 - accuracy: 0.6115
# Epoch 34/50
# 35/35 [==============================] - 8s 220ms/step - loss: 0.5916 - accuracy: 0.6745
# Epoch 35/50
# 35/35 [==============================] - 8s 219ms/step - loss: 0.5052 - accuracy: 0.7474
# Epoch 36/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.3588 - accuracy: 0.8486
# Epoch 37/50
# 35/35 [==============================] - 8s 219ms/step - loss: 0.2203 - accuracy: 0.9077
# Epoch 38/50
# 35/35 [==============================] - 8s 219ms/step - loss: 0.1568 - accuracy: 0.9273
# Epoch 39/50
# 35/35 [==============================] - 8s 221ms/step - loss: 0.1271 - accuracy: 0.9404
# Epoch 40/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.1208 - accuracy: 0.9436
# Epoch 41/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.1117 - accuracy: 0.9465
# Epoch 42/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.0870 - accuracy: 0.9560
# Epoch 43/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.0873 - accuracy: 0.9585
# Epoch 44/50
# 35/35 [==============================] - 8s 218ms/step - loss: 0.0749 - accuracy: 0.9653
# Epoch 45/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.0676 - accuracy: 0.9654
# Epoch 46/50
# 35/35 [==============================] - 8s 227ms/step - loss: 0.0604 - accuracy: 0.9709
# Epoch 47/50
# 35/35 [==============================] - 8s 229ms/step - loss: 0.0822 - accuracy: 0.9618
# Epoch 48/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.0661 - accuracy: 0.9712
# Epoch 49/50
# 35/35 [==============================] - 8s 228ms/step - loss: 0.0487 - accuracy: 0.9766
# Epoch 50/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.0401 - accuracy: 0.9819
# 0.8786984893179584 0.8743372216330859 0.8844984802431611 0.8831615120274914 0.8793884988001066 1.1599549452757412

# %%
accuracy = num_hit / num_total
prec = num_true_pos / (num_true_pos + num_false_pos)
recall = num_true_pos / num_pos
spec = num_true_neg / (num_true_neg + num_false_neg)
f1 = 2. * prec * recall / (prec + recall)
mcc = (num_true_pos * num_true_neg - num_false_pos * num_false_neg) / ((num_true_pos + num_true_neg) * (num_true_pos + num_false_neg) * (num_false_pos + num_true_neg) * (num_false_pos + num_false_neg)) ** 0.5
print (accuracy, prec, recall, f1)
